# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv(r"C:\Users\nk424\OneDrive\Scans\Desktop\training\Sample_Data\student_clustering.csv")
df.head()
# Out:
#    cgpa   iq
# 0  5.13   88
# 1  5.90  113
# 2  8.36   93
# 3  8.27   97
# 4  5.45  110

# %%
import matplotlib.pyplot as plt
plt.scatter(df['cgpa'],df['iq'])

# %%
from sklearn.cluster import KMeans

# %%
wcss=[]
for i in range (1,11):
    km=KMeans(n_clusters=i)
    km.fit_predict(df)
    wcss.append(km.inertia_)

# %%
wcss
# Out:
# [29957.898288,
#  4184.14127,
#  2503.397581,
#  681.9696599999999,
#  576.1106016439909,
#  412.22876915069065,
#  354.0352530907327,
#  281.92637063135624,
#  220.47019258014885,
#  193.31391022671747]

# %%
plt.plot(range(1,11),wcss)
## 4 clustor giving lower value of wcss

# %%
x=df.iloc[:,:].values
km=KMeans(n_clusters=4)
y_pred=km.fit_predict(x)

# %%
y_pred
# Out:
# array([3, 2, 1, 1, 2, 2, 1, 0, 2, 1, 3, 2, 1, 3, 2, 1, 2, 1, 2, 2, 1, 3,
#        1, 3, 3, 1, 3, 0, 1, 2, 0, 2, 0, 2, 1, 1, 0, 2, 3, 2, 3, 1, 1, 3,
#        0, 0, 1, 2, 0, 2, 3, 3, 0, 1, 0, 2, 2, 0, 2, 0, 2, 1, 1, 0, 3, 0,
#        1, 3, 2, 1, 2, 0, 1, 3, 2, 0, 2, 0, 3, 1, 1, 0, 2, 3, 0, 3, 0, 2,
#        0, 2, 0, 0, 1, 3, 1, 1, 0, 1, 3, 0, 2, 3, 3, 0, 3, 3, 1, 3, 0, 0,
#        1, 0, 2, 2, 1, 0, 1, 2, 0, 3, 3, 2, 1, 0, 1, 3, 1, 2, 3, 1, 1, 2,
#        3, 3, 2, 0, 2, 3, 1, 1, 1, 3, 2, 3, 3, 0, 3, 0, 2, 3, 0, 3, 0, 0,
#        3, 1, 2, 0, 2, 1, 3, 0, 2, 1, 0, 3, 2, 3, 3, 0, 0, 2, 0, 3, 3, 1,
#        0, 2, 3, 0, 0, 2, 2, 2, 1, 3, 1, 1, 0, 2, 1, 1, 3, 3, 1, 3, 0, 2,
#        2, 0], dtype=int32)

# %%
x[y_pred==0,0]
# clusture 0 with dataset column0""cgpa"
# Out:
# array([8.8 , 9.18, 8.86, 8.83, 8.56, 8.96, 8.78, 8.45, 8.79, 8.81, 8.88,
#        9.07, 8.92, 8.75, 8.71, 8.86, 9.3 , 9.01, 8.97, 9.  , 8.76, 8.78,
#        9.23, 9.03, 9.13, 8.91, 8.98, 9.03, 8.86, 8.89, 8.97, 8.72, 8.93,
#        8.58, 8.94, 8.6 , 8.77, 8.81, 8.54, 8.97, 8.91, 8.68, 9.06, 8.9 ,
#        8.94, 8.91, 8.91, 8.95, 8.57, 8.82])

# %%
x[y_pred==0,1]
# Out:
# array([115., 119., 117., 118., 118., 116., 116., 119., 116., 115., 115.,
#        117., 118., 113., 116., 118., 117., 121., 116., 117., 117., 117.,
#        114., 118., 118., 119., 118., 118., 117., 118., 117., 119., 118.,
#        118., 117., 117., 117., 116., 118., 119., 117., 119., 120., 117.,
#        115., 115., 117., 116., 118., 117.])

# %%
plt.scatter(x[y_pred==0,0],x[y_pred==0,1],color='b')
plt.scatter(x[y_pred==1,0],x[y_pred==1,1],color='r')
plt.scatter(x[y_pred==2,0],x[y_pred==2,1],color='g')
plt.scatter(x[y_pred==3,0],x[y_pred==3,1],color='y')
