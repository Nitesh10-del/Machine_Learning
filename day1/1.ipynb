# %%
l1=[1,2,"python",10.50,"java"]
print(l1)
print(type(l1))

# %%
l1[2]='ML'  ##it is mutable
print(*l1)

# %%
if "java" in l1:
    print("yes")
else:
    print("no")

# %%
#append()
l1.append("CR")
print(*l1)

# %%
l1.insert(0,"KBC")
print(*l1)

# %%
#remove
l1.remove("CR")
print(*l1)

# %%
#pop=>remove last element
l1.pop()
l1

# %%
A=['a','b','c','d']
B=[1,2,3,4]
B.extend(A)
B

# %%
#tuple=> collection which is orderd and un-changable but allow duplicates
t=("java",1,2,3,4,"ram")
print(t)
print(type(t))

# %%
t[1]=1000 #unchangable
print(t)

# %%
t=("java",1,2,3,4,"ram","ram")## duplicacy allowed
t

# %%
#set => collection unorderd, un-indexed and no duplicacy allowed
set={0,20,30,40,50}
set

# %%
# print(set[4])#not supporting indexing

# %%
set.add(1)
set

# %%
set.remove(1)
set

# %%
set.add(50)#no duplicacy
set

# %%
set.discard(100)#remove=disgard  both are same
set

# %%
set2={'a','b','c','d'}
print(set|set2)

# %%
dict={"money":1000,"age":24,"name":"nitesh"}
dict
