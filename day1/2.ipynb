# %%
dict={"money":1000,"age":24,"name":"nitesh"}
dict
# Out:
# {'money': 1000, 'age': 24, 'name': 'nitesh'}

# %%
print(dict.values())
print(dict.keys())
# Out:
# dict_values([1000, 24, 'nitesh'])
# dict_keys(['money', 'age', 'name'])

# %%
dict.update({"age":509})
dict
# Out:
# {'money': 1000, 'age': 509, 'name': 'nitesh'}

# %%
dict.pop("age")
dict
# Out:
# {'money': 1000, 'name': 'nitesh'}

# %%
print(dict.popitem())
# Out:
# ('money', 1000)
