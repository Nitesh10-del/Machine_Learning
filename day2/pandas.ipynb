# %%
# pandas data structure
import pandas as pd
#from list crearte series
list=[5.5,15,7,8]
series=pd.Series(list,index=["a","b","c","d"],dtype=float)
series
# Out:
# a     5.5
# b    15.0
# c     7.0
# d     8.0
# dtype: float64

# %%
#creating sries fromm dictonary
series2=pd.Series({"a":10,"b":5,"c":17})
print(series2)
#slicing series
print(series2[0:2])
# min()
print(series2.min())
series2.max()
# Out:
# a    10
# b     5
# c    17
# dtype: int64
# a    10
# b     5
# dtype: int64
# 5
# 17

# %%
#pandas dataframe
# from list to dataframe
list=[5.5,6.5,'jai']
df=pd.DataFrame(list)
df
# Out:
#      0
# 0  5.5
# 1  6.5
# 2  jai

# %%
# from list of list
list=[1,2,3],[4,5,6],[7,8,9]
df=pd.DataFrame(list)
df
# Out:
#    0  1  2
# 0  1  2  3
# 1  4  5  6
# 2  7  8  9

# %%
# create dataframe from dictonary
d1=[{"Name":'Rohan',"Age":2},{"Name":'kunal',"Age":40,"DOB":"5/03/24"}]
df=pd.DataFrame(d1)
df
# Out:
#     Name  Age      DOB
# 0  Rohan    2      NaN
# 1  kunal   40  5/03/24

# %%
df2= pd.read_csv(r"C:\Users\nk424\OneDrive\Scans\Desktop\training\Sample_Data\Result_Student.csv")
df2.head()
# Out:
#    Student ID  Class  Study hrs  Social Media usage hrs  Percentage  Grade  \
# 0        1001     10          2                       3          50    Avg
# 1        1002     10          6                       2          80  Vgood
# 2        1003     10          3                       2          60   Good
# 3        1004     11          0                       1          45   Fail
# 4        1005     12          5                       2          75   Good
#
#    Gender
# 0  Female
# 1    Male
# 2  Female
# 3    Male
# 4  Female

# %%
df2.shape
df2.size
# Out:
# 35

# %%
df1 = pd.read_csv(r"C:\Users\nk424\OneDrive\Scans\Desktop\training\Sample_Data\IMP.csv")
df1
# Out:
#    Student ID  Class  Study hrs  Sleeping hrs  Social Media usage hrs  \
# 0        1001   10.0          2             9                       3
# 1        1002   10.0          6             8                       2
# 2        1003    NaN          3             8                       2
# 3        1004    NaN          0            10                       1
# 4        1005   11.0          4             7                       2
# 5        1006   11.0         10             7                       0
# 6        1007   12.0          4             6                       0
# 7        1008   12.0         10             6                       2
# 8        1009   12.0          2             8                       2
# 9        1010   12.0          6             9                       1
#
#    Mobile Games hrs  Percantege
# 0                 5        50.0
# 1                 0        80.0
# 2                 4        60.0
# 3                 5        45.0
# ...

# %%
df1.shape
# Out:
# (10, 7)

# %%
df1 = pd.read_csv(r"C:\Users\nk424\OneDrive\Scans\Desktop\training\Sample_Data\IMP.csv") #usecols=[0,5]
print(df1.head())
df1.tail()
# Out:
#    Student ID  Class  Study hrs  Sleeping hrs  Social Media usage hrs  \
# 0        1001   10.0          2             9                       3
# 1        1002   10.0          6             8                       2
# 2        1003    NaN          3             8                       2
# 3        1004    NaN          0            10                       1
# 4        1005   11.0          4             7                       2
#
#    Mobile Games hrs  Percantege
# 0                 5        50.0
# 1                 0        80.0
# 2                 4        60.0
# 3                 5        45.0
# 4                 0        75.0
#    Student ID  Class  Study hrs  Sleeping hrs  Social Media usage hrs  \
# 5        1006   11.0         10             7                       0
# 6        1007   12.0          4             6                       0
# 7        1008   12.0         10             6                       2
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 7 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Student ID              10 non-null     int64
#  1   Class                   8 non-null      float64
#  2   Study hrs               10 non-null     int64
#  3   Sleeping hrs            10 non-null     int64
#  4   Social Media usage hrs  10 non-null     int64
#  5   Mobile Games hrs        10 non-null     int64
#  6   Percantege              8 non-null      float64
# dtypes: float64(2), int64(5)
# memory usage: 692.0 bytes

# %%
df1.describe()
# Out:
#        Student ID      Class  Study hrs  Sleeping hrs  Social Media usage hrs  \
# count    10.00000   8.000000     10.000     10.000000               10.000000
# mean   1005.50000  11.250000      4.700      7.800000                1.500000
# std       3.02765   0.886405      3.335      1.316561                0.971825
# min    1001.00000  10.000000      0.000      6.000000                0.000000
# 25%    1003.25000  10.750000      2.250      7.000000                1.000000
# 50%    1005.50000  11.500000      4.000      8.000000                2.000000
# 75%    1007.75000  12.000000      6.000      8.750000                2.000000
# max    1010.00000  12.000000     10.000     10.000000                3.000000
#
#        Mobile Games hrs  Percantege
# count         10.000000    8.000000
# mean           1.800000   68.875000
# std            2.347576   17.892037
# min            0.000000   45.000000
# 25%            0.000000   57.500000
# 50%            0.000000   67.500000
# ...

# %%
import matplotlib.pyplot as plt
plt.boxplot(df1['Student ID'])
plt.title("Box Plot of RESULT")
plt.show()

# %%
df1.isnull().sum()
# Out:
# Student ID                0
# Class                     2
# Study hrs                 0
# Sleeping hrs              0
# Social Media usage hrs    0
# Mobile Games hrs          0
# Percantege                2
# dtype: int64

# %%
# dropna
df_new=df1.dropna(axis=1)#axis=1  => drop column #axis=0 => drop rows
df_new
# Out:
#    Student ID  Study hrs  Sleeping hrs  Social Media usage hrs  \
# 0        1001          2             9                       3
# 1        1002          6             8                       2
# 2        1003          3             8                       2
# 3        1004          0            10                       1
# 4        1005          4             7                       2
# 5        1006         10             7                       0
# 6        1007          4             6                       0
# 7        1008         10             6                       2
# 8        1009          2             8                       2
# 9        1010          6             9                       1
#
#    Mobile Games hrs
# 0                 5
# 1                 0
# 2                 4
# 3                 5
# 4                 0
# 5                 0
# 6                 0
# 7                 0
# 8                 4
# 9                 0

# %%
df_new.shape
# Out:
# (10, 5)

# %%
df_new=df1.dropna(thresh=1) #thresh=1 means keep the row if it has at least 1 non-missing value.
df_new.shape
# Out:
# (10, 7)

# %%
df1.fillna(value=10,inplace=True)# inplace=1 => It tells pandas to change the original dataframe directly.
df1.isnull().sum()
# Out:
# Student ID                0
# Class                     0
# Study hrs                 0
# Sleeping hrs              0
# Social Media usage hrs    0
# Mobile Games hrs          0
# Percantege                0
# dtype: int64

# %%
df1
# Out:
#    Student ID  Class  Study hrs  Sleeping hrs  Social Media usage hrs  \
# 0        1001   10.0          2             9                       3
# 1        1002   10.0          6             8                       2
# 2        1003   10.0          3             8                       2
# 3        1004   10.0          0            10                       1
# 4        1005   11.0          4             7                       2
# 5        1006   11.0         10             7                       0
# 6        1007   12.0          4             6                       0
# 7        1008   12.0         10             6                       2
# 8        1009   12.0          2             8                       2
# 9        1010   12.0          6             9                       1
#
#    Mobile Games hrs  Percantege
# 0                 5        50.0
# 1                 0        80.0
# 2                 4        60.0
# 3                 5        45.0
# ...

# %%
df4=df1.fillna({"Class":11.0,"Percantege":68.89})
df4
# Out:
#    Student ID  Class  Study hrs  Sleeping hrs  Social Media usage hrs  \
# 0        1001   10.0          2             9                       3
# 1        1002   10.0          6             8                       2
# 2        1003   10.0          3             8                       2
# 3        1004   10.0          0            10                       1
# 4        1005   11.0          4             7                       2
# 5        1006   11.0         10             7                       0
# 6        1007   12.0          4             6                       0
# 7        1008   12.0         10             6                       2
# 8        1009   12.0          2             8                       2
# 9        1010   12.0          6             9                       1
#
#    Mobile Games hrs  Percantege
# 0                 5        50.0
# 1                 0        80.0
# 2                 4        60.0
# 3                 5        45.0
# ...
